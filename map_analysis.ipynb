# %%
import os
import pandas as pd
import umap
import umap.plot
from sklearn.datasets import load_digits

# %%
digits = load_digits()

mapper = umap.UMAP().fit(digits.data)
umap.plot.points(mapper, labels=digits.target)
# Out:
# <AxesSubplot:>

# %%
database = pd.read_csv('SSID_Data.csv')
database.head(5)
# Out:
#    Unnamed: 0  LocationID    SessionID GroupID  RecordID Language  Lockdown  \
# 0           0  CamdenTown  CamdenTown1   CT101     525.0  English         0
# 1           1  CamdenTown  CamdenTown1   CT101     561.0  English         0
# 2           2  CamdenTown  CamdenTown1   CT101     526.0  English         0
# 3           3  CamdenTown  CamdenTown1   CT102     560.0  English         0
# 4           4  CamdenTown  CamdenTown1   CT103     527.0  English         0
#
#             start_time             end_time   latitude  ...  \
# 0  2019-05-02 11:40:00  2019-05-02 11:43:00  51.539124  ...
# 1  2019-05-02 11:40:00  2019-05-02 11:43:00  51.539124  ...
# 2  2019-05-02 11:41:00  2019-05-02 11:44:00  51.539124  ...
# 3  2019-05-02 11:50:00  2019-05-02 11:53:00  51.539124  ...
# 4  2019-05-02 11:49:00  2019-05-02 11:54:00  51.539124  ...
#
#    FS_Avg,arith(vacil)  I_HM_Avg,arith(iu)  Ton_HM_Avg,arith(tuHMS)  \
# 0              0.01700               0.358                    0.309
# 1              0.01700               0.358                    0.309
# 2              0.01700               0.358                    0.309
# 3              0.01790               0.362                    0.268
# 4              0.00889               0.370                    0.193
#
#    LZeq_L(dB(SPL))  LAeq_L(A)(dB(SPL))  LA10_LA90(dB(SPL))  \
# 0            79.72               70.07                7.78
# 1            79.72               70.07                7.78
# 2            79.72               70.07                7.78
# 3            80.27               71.26                8.38
# 4            76.79               66.71                4.23
#
#    LCeq_LAeq(dB(SPL))  LC10_LC90(dB(SPL))  RA_2D_cp(cPa)  PA(Zwicker)
# 0                7.81                8.11           14.3    36.019181
# 1                7.81                8.11           14.3    36.019181
# 2                7.81                8.11           14.3    36.019181
# 3                6.25                7.82           14.7    40.523268
# 4                7.61                3.99           13.4    27.108635
#
# [5 rows x 79 columns]

# %%
database.describe()
# Out:
#         Unnamed: 0      RecordID     Lockdown     latitude    longitude  \
# count  1909.000000   1302.000000  1909.000000  1302.000000  1302.000000
# mean    954.000000    758.415515     0.299109    50.911195     1.128755
# std     551.225151    910.521989     0.457988     1.832944     3.752435
# min       0.000000      1.000000     0.000000    45.431837    -0.153024
# 25%     477.000000    334.250000     0.000000    51.514220    -0.132300
# 50%     954.000000    700.500000     0.000000    51.523373    -0.126202
# 75%    1431.000000   1048.750000     1.000000    51.526900    -0.100162
# max    1908.000000  10018.000000     1.000000    51.539196    12.354908
#
#            Traffic        Other        Human      Natural  ISOPleasant  ...  \
# count  1301.000000  1301.000000  1301.000000  1301.000000  1302.000000  ...
# mean      2.652575     2.329746     3.112221     2.492698     0.272583  ...
# std       1.104175     1.141369     0.978859     1.184899     0.405349  ...
# min       1.000000     1.000000     1.000000     1.000000    -1.000000  ...
# 25%       2.000000     1.000000     2.000000     2.000000     0.000000  ...
# 50%       3.000000     2.000000     3.000000     2.000000     0.310700  ...
# 75%       4.000000     3.000000     4.000000     3.000000     0.603600  ...
# max       5.000000     5.000000     5.000000     5.000000     1.000000  ...
#
#        FS_Avg,arith(vacil)  I_HM_Avg,arith(iu)  Ton_HM_Avg,arith(tuHMS)  \
# count          1743.000000         1743.000000              1743.000000
# mean              0.017222            0.395924                 0.199941
# std               0.016673            0.078790                 0.154362
# min               0.002530            0.197000                 0.017300
# 25%               0.007170            0.340000                 0.099100
# 50%               0.013300            0.384000                 0.161000
# 75%               0.021150            0.432500                 0.257000
# max               0.229000            1.110000                 1.440000
#
#        LZeq_L(dB(SPL))  LAeq_L(A)(dB(SPL))  LA10_LA90(dB(SPL))  \
# count      1743.000000         1743.000000         1743.000000
# mean         72.847636           61.302932            5.989954
# std           5.762566            7.630255            3.514965
# min          52.990000           42.270000            0.440000
# 25%          69.110000           55.060000            3.760000
# 50%          73.200000           61.930000            5.430000
# 75%          76.585000           67.100000            7.490000
# max          97.310000           86.310000           22.970000
#
#        LCeq_LAeq(dB(SPL))  LC10_LC90(dB(SPL))  RA_2D_cp(cPa)  PA(Zwicker)
# count         1743.000000         1743.000000    1743.000000  1743.000000
# mean             8.405542            5.888726      12.313373    22.656203
# std              4.222677            3.109413       2.114922    15.541479
# min             -0.290000            0.520000       7.420000     4.335480
# 25%              5.460000            3.580000      10.900000    11.878576
# 50%              8.080000            4.980000      12.200000    18.857770
# 75%             10.625000            7.535000      13.600000    30.945373
# max             26.280000           21.960000      33.000000   199.155517
#
# [8 rows x 65 columns]
